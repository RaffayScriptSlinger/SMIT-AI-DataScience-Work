# %% [markdown]
# ### PRINTING ANY THING IN PYTHON

# %%
name = "Raffay"

# %%
print(name)
# Out:
# Raffay

# %% [markdown]
# ### Concadination

# %%
name = "Raffay"
father_Name = "Sharjeel"

# %%
print("My Name is ",name ,"and my father name is ",father_Name)
print(f"My name is {name} and my father Name is {father_Name} Through F String ")
print("My Name is " + name + " and my father name is " + father_Name)
# Out:
# My Name is  Raffay and my father name is  Sharjeel
# My name is Raffay and my father Name is Sharjeel Through F String
# My Name is Raffay and my father name is Sharjeel

# %%
num_1 = 2
num_2 = "2"
print(str(num_1) + num_2)
# Out:
# 22

# %%
num_3 = 32.9
num_4 = 10
int(num_3 + num_4)
# Out:
# 42

# %% [markdown]
# ### Comments

# %% [markdown]
# ### Multi Line Comment

# %%
# Here Is AN Commet Example

# %%
"""
Hello 
How Are You 
Iam Raffay
"""

print("Code Running.....")
# Out:
# Code Running.....

# %% [markdown]
# ### Single Line Comment

# %%
# This An Single Line Comment

# %% [markdown]
# ### Type Check And Type Cast

# %%
name = "Raffay"
type(name)
# Out:
# str

# %%
num = 2
num = str(num)
type(num)
# Out:
# str

# %% [markdown]
# ### Input From The User

# %%
user_Input = input("Enter Your Name")
print("User Input Is",user_Input)
# Out:
# Enter Your Name Raffay
# User Input Is Raffay

# %% [markdown]
# ### Operators

# %%
a = 10
b = 3
a > b
# Out:
# True

# %%
a = 11
b = 18
a < b
# Out:
# True

# %%
a = 10 
b = 10 
a != b
# Out:
# False

# %% [markdown]
# ### Logical Operators

# %%
a = 10 
b = 12 
c = 14

a < b or a < c
# Out:
# True

# %%
a = True
not a
# Out:
# False

# %% [markdown]
# ### Conditional Statement

# %%
x = 2
y = 18

if x > y:
    print("X is Greater Then Y")
elif x < y:
    print("Y is Greater Then X")
else:
    print("Error")
# Out:
# Y is Greater Then X

# %% [markdown]
# ### LOOPS

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0 
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %% [markdown]
# ### List

# %%
lst = [1,2,3,4,5,6,7]
lst[0:3]
# Out:
# [1, 2, 3]

# %%
lst.append(8)

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.insert(8,9)

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lst.sort()

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
lst.reverse()

# %%
lst
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
lst.count(9)
# Out:
# 1

# %%
lst.index(1)
# Out:
# 8

# %%
lst.append([10,11])

# %%
lst
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, [10, 11]]

# %%
lst[9]
# Out:
# [10, 11]

# %%
lst[9][1]
# Out:
# 11

# %% [markdown]
# ### Tupple

# %%
tup = (10,20,30)

# %%
type(tup)
# Out:
# tuple

# %%
tup.index(10)
# Out:
# 0

# %%
tup.count(10)
# Out:
# 1

# %%
tup = list(tup)

# %% [markdown]
# ### Dictonary

# %%
student = {
    "ID" : "01",
    "Name" : "Raffay"
}

# %%
student["ID"]
# Out:
# '01'

# %%
student["ID"] = "001"

# %%
student["ID"]
# Out:
# '001'

# %%
student
# Out:
# {'ID': '001', 'Name': 'Raffay'}

# %%
student.pop("Name")
# Out:
# 'Raffay'

# %%
student
# Out:
# {'ID': '001'}

# %%
student.keys()
# Out:
# dict_keys(['ID'])

# %%
student.values()
# Out:
# dict_values(['001'])

# %%
for k,v in student.items():
    print(k,v)
# Out:
# ID 001

# %%
courses = {
    "course_01"  : {
    "Course_Id" : "01",
    "Course_Name" : "Python"
    },
    "course_02" : {
    "Course_Id" : "02",
    "Course_Name" : "Java"
    }
    
}

# %%
courses[ "course_01"]["Course_Id"]
# Out:
# '01'

# %%
for i,j in courses.items():
    print(i,j)
# Out:
# course_01 {'Course_Id': '01', 'Course_Name': 'Python'}
# course_02 {'Course_Id': '02', 'Course_Name': 'Java'}
