# %% [markdown]
# ### Banking Sysytem

# %%
All_Account = []

# %%
print("Welcome To My Banking System")
name = input("Enter Your Name")
Age = int(input("Enter Your Age"))
cnic = int(input("Eneter Your Cnic"))
# Out:
# Welcome To My Banking System
# Enter Your Name Raffay Sharjeel
# Enter Your Age 19
# Eneter Your Cnic 4220177313011

# %%
import random

# %%
def user_Account():
    print("User Account Has Been Created")
    account_num = random.randint(500,1000)
    print("Your Account Is Created With",name,"Name")
    print("Your Age Is",Age)
    print("Your Cnic Is",cnic)
    print("Account Number is",account_num)
    my_Account_Details = {
    
    "Name" : name,
    "Age" : Age,
    "Cnic" : cnic,
    "Account Number" : account_num
    }
    All_Account.append(my_Account_Details)

# %%
user_Account()
# Out:
# User Account Has Been Created
# Your Account Is Created With Raffay Sharjeel Name
# Your Age Is 19
# Your Cnic Is 4220177313011
# Account Number is 636

# %%
All_Account
# Out:
# [{'Name': 'Shayan', 'Age': 16, 'Cnic': 422017752, 'Account Number': 943},
#  {'Name': 'Raffay', 'Age': 19, 'Cnic': 4220177313011, 'Account Number': 808},
#  {'Name': 'Raffay Sharjeel',
#   'Age': 19,
#   'Cnic': 4220177313011,
#   'Account Number': 636}]

# %% [markdown]
# ### Lambda

# %%
sum_ = lambda *x: sum(x)

# %%
sum_
# Out:
# <function __main__.<lambda>(*x)>

# %%
sum_()
# Out:
# 0

# %%
sum_(1,2,3,4,5,6,7,8,9)
# Out:
# 45
