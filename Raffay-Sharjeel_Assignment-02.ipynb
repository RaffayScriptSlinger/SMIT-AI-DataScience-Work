# %% [markdown]
# ### 1) Area of a Rectangle:
# ###    Write a Python program to calculate the area of a rectangle. Use the formula:
# ###    𝐴𝒓𝒆𝒂 = 𝒍𝒆𝒏𝒈𝒕𝒉 × 𝒘𝒊𝒅𝒕𝒉
# ###    Take length and width as inputs from the user.

# %%
Length = int(input("Enter Length"))
𝒘𝒊𝒅𝒕𝒉 = int(input("Enter 𝒘𝒊𝒅𝒕𝒉"))
Area = Length * 𝒘𝒊𝒅𝒕𝒉
print("****" , Area , "****" )
# Out:
# Enter Length 5
# Enter 𝒘𝒊𝒅𝒕𝒉 10
# **** 50 ****

# %% [markdown]
# ### 2) Circumference of a Circle:
# ###    Write a Python program to calculate the circumference of a circle. Use the formula:
# ###    𝑪𝒊𝒓𝒄𝒖𝒎𝒇𝒆𝒓𝒆𝒏𝒄𝒆 = 𝟐𝝅𝒓
# ###    Take the radius r as input from the user.

# %%
Radius = int(input("Enter Your Radius So I can calculate a Circumference "))
𝑪𝒊𝒓𝒄𝒖𝒎𝒇𝒆𝒓𝒆𝒏𝒄𝒆 = 2 * 3.14  * Radius
print("Circumference is ",𝑪𝒊𝒓𝒄𝒖𝒎𝒇𝒆𝒓𝒆𝒏𝒄𝒆)
# Out:
# Enter Your Radius So I can calculate a Circumference  5
# Circumference is  31.400000000000002

# %% [markdown]
# ### 3) Simple Interest:
# ### Write a Python program to calculate the simple interest. Use the formula:
# ### 𝑺𝒊𝒎𝒑𝒍𝒆 𝑰𝒏𝒕𝒆𝒓𝒆𝒔𝒕 = 𝑷𝒓𝒊𝒏𝒄𝒊𝒑𝒂𝒍 × 𝑹𝒂𝒕𝒆 × 𝑻𝒊𝒎𝒆
# ### Take Principal, Rate, and Time as inputs from the user.

# %%
Principle = eval(input("Enter The Principle"))
Rate = eval(input("Enter The Rate"))
Time = eval(input("Enter The Time"))
Simple_Interest = Principle * Rate * Time
print("Simple Interest Is",Simple_Interest)
# Out:
# Enter The Principle 5
# Enter The Rate 2
# Enter The Time 2
# Simple Interest Is 20

# %% [markdown]
# ### 4) Speed of an Object:
# ### Write a Python program to calculate the speed of an object. Use the formula:
# ### 𝑆𝒑𝒆𝒆𝒅 = 𝑫𝒊𝒔𝒕𝒂𝒏𝒄𝒆 / 𝑻𝒊𝒎𝒆
# ### Take Distance and Time as inputs from the user.

# %%
Distance = eval(input("Enter A Distance"))
Time = eval(input("Enter A time"))
Speed = Distance / Time
print(Speed)
# Out:
# Enter A Distance 5
# Enter A time 3
# 1.6666666666666667

# %% [markdown]
# ### 5) BMI Calculator python

# %%
weight = float(input("Enter weight (kg): "))
height = float(input("Enter height (m): "))

bmi = weight / (height ** 2)

print("BMI:", bmi)
# Out:
# Enter weight (kg):  12.5
# Enter height (m):  10
# BMI: 0.125

# %% [markdown]
# ### 6) Force (Newton's Second Law)

# %%
m = float(input("Enter mass (kg): "))
a = float(input("Enter acceleration (m/s^2): "))

force = m * a

print("Force:", force)
# Out:
# Enter mass (kg):  12
# Enter acceleration (m/s^2):  1
# Force: 12.0

# %% [markdown]
# ### 7) Compound Interest (Amount)

# %%
P = float(input("Enter principal amount: "))
r = float(input("Enter annual interest rate (decimal): "))
n = int(input("Enter number of times compounded per year: "))
t = float(input("Enter time (years): "))

A = P * (1 + r / n) ** (n * t)

print("Total amount (A):", A)
# Out:
# Enter principal amount:  2
# Enter annual interest rate (decimal):  2
# Enter number of times compounded per year:  2
# Enter time (years):  4
# Total amount (A): 512.0

# %%
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = float(input("Enter side c: "))

perimeter = a + b + c

print("Perimeter of triangle:", perimeter)
# Out:
# Enter side a:  12
# Enter side b:  1.6
# Enter side c:  5
# Perimeter of triangle: 18.6

# %%
import math

r = float(input("Enter radius: "))

volume = (4 / 3) * math.pi * (r ** 3)

print("Volume of sphere:", volume)
# Out:
# Enter radius:  54
# Volume of sphere: 659583.6608064842

# %%
m = float(input("Enter mass (kg): "))
v = float(input("Enter velocity (m/s): "))

ke = 0.5 * m * (v ** 2)

print("Kinetic Energy:", ke)
# Out:
# Enter mass (kg):  21
# Enter velocity (m/s):  5
# Kinetic Energy: 262.5

# %%
import math

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

discriminant = b**2 - 4*a*c

if discriminant > 0:
    root1 = (-b + math.sqrt(discriminant)) / (2*a)
    root2 = (-b - math.sqrt(discriminant)) / (2*a)
    print("Two real roots:", root1, "and", root2)
elif discriminant == 0:
    root = -b / (2*a)
    print("One real root:", root)
else:
    real_part = -b / (2*a)
    imag_part = math.sqrt(-discriminant) / (2*a)
    print("Complex roots:",
          f"{real_part} + {imag_part}i and {real_part} - {imag_part}i")
# Out:
# Enter a:  45
# Enter b:  54
# Enter c:  54
# Complex roots: -0.6 + 0.916515138991168i and -0.6 - 0.916515138991168i

# %%
C = float(input("Enter temperature in Celsius: "))

F = (9/5) * C + 32

print("Temperature in Fahrenheit:", F)
# Out:
# Enter temperature in Celsius:  12
# Temperature in Fahrenheit: 53.6

# %%
G = 6.674e-11  

m1 = float(input("Enter mass m1 (kg): "))
m2 = float(input("Enter mass m2 (kg): "))
r = float(input("Enter distance between centers (m): "))

F = G * m1 * m2 / (r ** 2)

print("Gravitational force:", F)
# Out:
# Enter mass m1 (kg):  12
# Enter mass m2 (kg):  1
# Enter distance between centers (m):  5
# Gravitational force: 3.2035199999999995e-11

# %%
import math

r = float(input("Enter radius: "))
h = float(input("Enter height: "))

volume = math.pi * (r ** 2) * h

print("Volume of cylinder:", volume)
# Out:
# Enter radius:  2
# Enter height:  5
# Volume of cylinder: 62.83185307179586

# %%
F = float(input("Enter force: "))
A = float(input("Enter area: "))

P = F / A

print("Pressure:", P)
# Out:
# Enter force:  5
# Enter area:  5
# Pressure: 1.0

# %%
V = float(input("Enter voltage: "))
I = float(input("Enter current: "))

P = V * I

print("Electric power:", P)
# Out:
# Enter voltage:  4
# Enter current:  2
# Electric power: 8.0

# %%
import math

r = float(input("Enter radius: "))

perimeter = 2 * math.pi * r

print("Perimeter (circumference) of circle:", perimeter)
# Out:
# Enter radius:  21
# Perimeter (circumference) of circle: 131.94689145077132

# %%
PV = float(input("Enter present value (PV): "))
r = float(input("Enter annual interest rate (decimal): "))
t = float(input("Enter time (years): "))

FV = PV * (1 + r) ** t

print("Future value (FV):", FV)
# Out:
# Enter present value (PV):  5
# Enter annual interest rate (decimal):  5
# Enter time (years):  5
# Future value (FV): 38880.0

# %%
import math

f = float(input("Enter force: "))
d = float(input("Enter distance: "))
theta_deg = float(input("Enter angle in degrees: "))

theta_rad = math.radians(theta_deg)
W = f * d * math.cos(theta_rad)

print("Work done:", W)
# Out:
# Enter force:  1
# Enter distance:  5
# Enter angle in degrees:  5
# Work done: 4.9809734904587275

# %%
m = float(input("Enter mass: "))
c = float(input("Enter specific heat capacity: "))
T_initial = float(input("Enter initial temperature: "))
T_final = float(input("Enter final temperature: "))

delta_T = T_final - T_initial
Q = m * c * delta_T

print("Heat transferred Q:", Q)
# Out:
# Enter mass:  4
# Enter specific heat capacity:  4
# Enter initial temperature:  4
# Enter final temperature:  4
# Heat transferred Q: 0.0
