# %%
name = "Raffay"

# %%
name
# Out:
# 'Raffay'

# %%
lst = ["Raffay","Sharjeel","Shayan"]

# %%
lst
# Out:
# ['Raffay', 'Sharjeel', 'Shayan']

# %%
lst.append("Rehan")

# %%
lst
# Out:
# ['Raffay', 'Sharjeel', 'Shayan', 'Rehan']

# %%
type(lst)
# Out:
# list

# %%
name = "raffay"

# %%
name.upper()
# Out:
# 'RAFFAY'

# %%
lst[1:4]
# Out:
# ['Sharjeel', 'Shayan', 'Rehan']

# %%
lst[::2]
# Out:
# ['Raffay', 'Shayan', 'S', 'a', 'a', 'S', 'a', 'a', 'S', 'a', 'a']

# %%
lst_2 =  lst[2]

# %%
lst[-1::2]
# Out:
# ['n']

# %%
print(lst.extend(lst_2))
# Out:
# None

# %%
lst.insert(0,lst_2)

# %%
lst
# Out:
# ['Shayan',
#  'Raffay',
#  'Sharjeel',
#  'Shayan',
#  'Rehan',
#  'S',
#  'h',
#  'a',
#  'y',
#  'a',
#  'n',
#  'S',
#  'h',
#  'a',
#  'y',
#  'a',
#  'n',
#  'S',
#  'h',
#  'a',
#  'y',
#  'a',
#  'n',
#  'S',
#  'h',
#  'a',
#  'y',
#  'a',
#  'n']

# %%
Raffay_List = [1,2,3,4,5,6,7,8]

# %%
Raffay_List.pop()
# Out:
# 8

# %%
Raffay_List
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
Raffay_List.remove(5)

# %%
Raffay_List
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
Raffay_List.clear
# Out:
# <function list.clear()>

# %%
Raffay_List
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
house = {
    1 : "Raffay",
    "name" : "sd"
}

# %%
house["name"]
# Out:
# 'sd'

# %%
house.values()
# Out:
# dict_values(['Raffay'])

# %%
house
# Out:
# {1: 'Raffay'}

# %%
house.items()
# Out:
# dict_items([(1, 'Raffay')])

# %%
std = {"name":"Raffay","Age":"19","Class": "12"}

# %%
abc = {"group":"B"}

# %%
my_Set = {1,2,2,3}

# %%
my_Set
# Out:
# {1, 2, 3}

# %%
type(my_Set)
# Out:
# set

# %%
my_Set.add(21)

# %%
my_Set
# Out:
# {1, 2, 3, 21}

# %%
my_Set.remove(2)

# %%
my_Set.discard(1)

# %%
my_Set
# Out:
# {3, 21}

# %%
my_Set.pop()
# Out:
# 3

# %%
tup =(0,2,3,5,my_Set)

# %%
tup
# Out:
# (0, 2, 3, 5, {21})
